# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import os
from tensorflow.keras import models, layers, callbacks

# %%
# Checking GPU 

print(tf.test.gpu_device_name())
# Out:
# /device:GPU:0

# %%
# CONSTANTS

IMAGE_SIZE=256
BATCH_SIZE=32
EPOCHS=50
CHANNELS=3
TRAIN_SIZE=0.7
VALIDATION_SIZE=0.15
TEST_SIZE=0.15

# %%
# LOADING IMAGES

data = tf.keras.preprocessing.image_dataset_from_directory(
    directory="Plantvillage\\Potato",
    image_size=(IMAGE_SIZE,IMAGE_SIZE),
    batch_size=BATCH_SIZE,
    shuffle=True,

)

print("\n""Class names:", data.class_names)
# Out:
# Found 2152 files belonging to 3 classes.
#
# Class names: ['Potato___Early_blight', 'Potato___Late_blight', 'Potato___healthy']

# %%
# Printing 6 images from the batch

plt.figure(figsize=(12,12))

for image_batch, label_batch in data.take(1):
    for i in range(6):
        plt.subplot(3,3,i+1)
        plt.imshow(image_batch[i].numpy().astype("uint8"))
        plt.title(data.class_names[label_batch[i]])
        plt.axis("off")

# %%
# Splitting data for train, validation and test

def train_test_split(data, TRAIN_SIZE, VALIDATION_SIZE, TEST_SIZE):

    train_data = data.take(int(TRAIN_SIZE * len(data)))
    validation_data = data.skip(int(TRAIN_SIZE * len(data))).take(int(VALIDATION_SIZE * len(data)))
    test_data = data.skip(int(TRAIN_SIZE * len(data))).skip(int(VALIDATION_SIZE * len(data)))
    
    return train_data, validation_data, test_data

train_data, validation_data, test_data = train_test_split(data, TRAIN_SIZE, VALIDATION_SIZE, TEST_SIZE)

print("Length of train data:",len(train_data))
print("Length of validation data:",len(validation_data))
print("Length of test data:",len(test_data))
# Out:
# Length of train data: 47
# Length of validation data: 10
# Length of test data: 11

# %%
# Caching and pre-fetching data

train_data = train_data.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
validation_data = validation_data.cache().prefetch(buffer_size=tf.data.AUTOTUNE)
test_data = test_data.cache().prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
# Pre-processing and augmentation

resize_rescale = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    tf.keras.layers.experimental.preprocessing.Rescaling(1/255)
])

data_augment = tf.keras.Sequential([
    tf.keras.layers.experimental.preprocessing.RandomFlip("horizontal_and_vertical"),
    tf.keras.layers.experimental.preprocessing.RandomRotation(0.2)
])

# %%
# creating model

INPUT_SHAPE=(1,IMAGE_SIZE,IMAGE_SIZE,CHANNELS)
n_classes=len(data.class_names)

model = tf.keras.models.Sequential([
    resize_rescale,
    data_augment,
    layers.Conv2D(filters=32, kernel_size=(3,3), activation='relu', input_shape=INPUT_SHAPE),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Conv2D(32, (3,3), activation='relu'),
    layers.MaxPool2D((2,2)),
    layers.Flatten(),
    layers.Dense(32, activation='relu'),
    layers.Dense(n_classes, activation='softmax')
])


model.build(input_shape=INPUT_SHAPE)
model.compile(
    loss=['SparseCategoricalCrossentropy'], 
    metrics=['accuracy'], 
    optimizer='adam')

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (1, 256, 256, 3)          0
# _________________________________________________________________
# sequential_1 (Sequential)    (1, 256, 256, 3)          0
# _________________________________________________________________
# conv2d (Conv2D)              (1, 254, 254, 32)         896
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (1, 127, 127, 32)         0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (1, 125, 125, 32)         9248
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (1, 62, 62, 32)           0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (1, 60, 60, 32)           9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (1, 30, 30, 32)           0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (1, 28, 28, 32)           9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (1, 14, 14, 32)           0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (1, 12, 12, 32)           9248
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (1, 6, 6, 32)             0
# _________________________________________________________________
# flatten (Flatten)            (1, 1152)                 0
# _________________________________________________________________
# dense (Dense)                (1, 32)                   36896
# _________________________________________________________________
# dense_1 (Dense)              (1, 3)                    99
# =================================================================
# Total params: 74,883
# Trainable params: 74,883
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Training the model with earlystopping 

early_stop=callbacks.EarlyStopping(monitor='val_loss', patience=5, min_delta=0.001, mode='min')
tf.autograph.set_verbosity(0)

history = model.fit(
    train_data,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=validation_data,
    callbacks=[early_stop]
)
# Out:
# Epoch 1/50
# 47/47 [==============================] - 6s 66ms/step - loss: 0.9072 - accuracy: 0.4747 - val_loss: 0.9083 - val_accuracy: 0.6344
# Epoch 2/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.7384 - accuracy: 0.6955 - val_loss: 0.5801 - val_accuracy: 0.7875
# Epoch 3/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.4694 - accuracy: 0.8424 - val_loss: 0.4846 - val_accuracy: 0.8156
# Epoch 4/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.4121 - accuracy: 0.8511 - val_loss: 0.4067 - val_accuracy: 0.8250
# Epoch 5/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.3991 - accuracy: 0.8531 - val_loss: 0.4388 - val_accuracy: 0.8094
# Epoch 6/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.3633 - accuracy: 0.8604 - val_loss: 0.3712 - val_accuracy: 0.8375
# Epoch 7/50
# 47/47 [==============================] - 2s 49ms/step - loss: 0.3254 - accuracy: 0.8624 - val_loss: 0.3260 - val_accuracy: 0.8562
# Epoch 8/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.2827 - accuracy: 0.8723 - val_loss: 0.2304 - val_accuracy: 0.9094
# Epoch 9/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1994 - accuracy: 0.9309 - val_loss: 0.2121 - val_accuracy: 0.9312
# Epoch 10/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.2042 - accuracy: 0.9269 - val_loss: 0.1971 - val_accuracy: 0.9281
# Epoch 11/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1806 - accuracy: 0.9328 - val_loss: 0.1682 - val_accuracy: 0.9469
# Epoch 12/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1559 - accuracy: 0.9415 - val_loss: 0.1788 - val_accuracy: 0.9375
# Epoch 13/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1749 - accuracy: 0.9388 - val_loss: 0.1361 - val_accuracy: 0.9531
# Epoch 14/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1512 - accuracy: 0.9435 - val_loss: 0.1410 - val_accuracy: 0.9594
# Epoch 15/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1409 - accuracy: 0.9488 - val_loss: 0.1546 - val_accuracy: 0.9563
# Epoch 16/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1426 - accuracy: 0.9495 - val_loss: 0.1275 - val_accuracy: 0.9688
# Epoch 17/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.1598 - accuracy: 0.9468 - val_loss: 0.1484 - val_accuracy: 0.9594
# Epoch 18/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1279 - accuracy: 0.9521 - val_loss: 0.1154 - val_accuracy: 0.9656
# Epoch 19/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1369 - accuracy: 0.9501 - val_loss: 0.1235 - val_accuracy: 0.9594
# Epoch 20/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1230 - accuracy: 0.9614 - val_loss: 0.1189 - val_accuracy: 0.9625
# Epoch 21/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1590 - accuracy: 0.9368 - val_loss: 0.1348 - val_accuracy: 0.9531
# Epoch 22/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1536 - accuracy: 0.9475 - val_loss: 0.1052 - val_accuracy: 0.9688
# Epoch 23/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1253 - accuracy: 0.9568 - val_loss: 0.1219 - val_accuracy: 0.9594
# Epoch 24/50
# 47/47 [==============================] - 2s 49ms/step - loss: 0.1218 - accuracy: 0.9535 - val_loss: 0.1013 - val_accuracy: 0.9688
# Epoch 25/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1227 - accuracy: 0.9535 - val_loss: 0.0995 - val_accuracy: 0.9688
# Epoch 26/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.1031 - accuracy: 0.9707 - val_loss: 0.0768 - val_accuracy: 0.9750
# Epoch 27/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.1045 - accuracy: 0.9661 - val_loss: 0.1019 - val_accuracy: 0.9750
# Epoch 28/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0905 - accuracy: 0.9681 - val_loss: 0.0788 - val_accuracy: 0.9812
# Epoch 29/50
# 47/47 [==============================] - 2s 47ms/step - loss: 0.0999 - accuracy: 0.9608 - val_loss: 0.0811 - val_accuracy: 0.9719
# Epoch 30/50
# 47/47 [==============================] - 2s 46ms/step - loss: 0.0966 - accuracy: 0.9674 - val_loss: 0.0839 - val_accuracy: 0.9781
# Epoch 31/50
# 47/47 [==============================] - 2s 48ms/step - loss: 0.1133 - accuracy: 0.9648 - val_loss: 0.0832 - val_accuracy: 0.9750

# %%
plt.figure(figsize=(15,8))

plt.subplot(1,2,1)
plt.plot(range(len(history.history['loss'])), history.history['loss'], label="Training loss")
plt.plot(range(len(history.history['val_loss'])), history.history['val_loss'], label="Validation loss")

plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Loss graph')
plt.legend()

plt.subplot(1,2,2)
plt.plot(range(len(history.history['accuracy'])), history.history['accuracy'], label="Training accuracy")
plt.plot(range(len(history.history['val_accuracy'])), history.history['val_accuracy'], label="Validation accuracy")

plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Accuracy graph')
plt.legend()

# %%
# Image prediction

def prediction(model,img):
    
    prediction_prob_list = model.predict(img)
    predicted_class = data.class_names[np.argmax(prediction_prob_list)]
    predicted_probability = round(np.max(prediction_prob_list)*100,2)
    
    return (predicted_class, predicted_probability)

for image_batch, label_batch in test_data.take(1):
    
    plt.figure(figsize=(15,12))
    
    for j in range(4):
        
        plt.subplot(2,2,j+1)
        predicted_class, predicted_probability = prediction(model, image_batch[j].numpy().reshape(INPUT_SHAPE))
        plt.imshow(image_batch[j].numpy().astype('uint8'))
        plt.title('Actual label: {} \n Predicted label: {} \n Prediction confidence: {}%'.format(data.class_names[label_batch[j]], predicted_class, predicted_probability))
        plt.axis('off')

# %%
# Saving models

SAVE_PATH="./Saved_models/Potato/"

if os.listdir(SAVE_PATH):
    model_version = int(max([i for i in os.listdir(SAVE_PATH)]))+1
else:
    model_version=1

model.save(SAVE_PATH+str(model_version))
# Out:
# INFO:tensorflow:Assets written to: ./Saved_models/Potato/4\assets
